# %%
import pandas as pd
import numpy as np
import os

import statsmodels.api as sm

from sklearn.decomposition import PCA
from sklearn import preprocessing

def minmaxscaler_for_train(factor, std = 3):
    factorInfor = pd.DataFrame(index=['mean', 'std', 'up', 'down', 'min', 'max'], columns=factor.columns)
    
    factor_mean = factor.mean()
    factor_std = factor.std()
    factorInfor.loc['mean'] = factor_mean
    factorInfor.loc['std'] = factor_std
    
    factor_max = factor.max()
    factor_min = factor.min()
    factorInfor.loc['min'] = factor_min
    factorInfor.loc['max'] = factor_max
    
    factor_normal = pd.DataFrame(index=factor.index, columns=factor.columns) 
    for column in factor.columns:
        fac = factor[column].copy()
        fac_max = factor_max[column]
        fac_min = factor_min[column]
        factor_normal.loc[:, column] = (fac - fac_min) / (fac_max - fac_min)
    
    return factor_normal, factorInfor

def minmaxscaler_for_test(factor, factorInfor):
    factor_min = factorInfor.loc['min']
    factor_max = factorInfor.loc['max']
    
    factor_normal = pd.DataFrame(index=factor.index, columns=factor.columns) 
    for column in factor.columns:
        fac = factor[column].copy()
        fac_max = factor_max[column]
        fac_min = factor_min[column]
        factor_normal.loc[:, column] = (fac - fac_min) / (fac_max - fac_min)
    
    return factor_normal

# %%
begin_date = pd.Timestamp("1980-01-30")
end_date = pd.Timestamp("2009-12-01")
datapath = "../data"
rawpath = "../data/raw"

# %%
LogExcessReturn = pd.read_csv(os.path.join(datapath, "log_excess_return.csv"))
LogExcessReturn = LogExcessReturn.set_index("Date")
LogExcessReturn.index = pd.to_datetime(LogExcessReturn.index)
LogExcessReturn = LogExcessReturn.loc[begin_date: end_date]

# %%
LogExcessReturn.index
# Out:
# DatetimeIndex(['1980-01-31', '1980-02-29', '1980-03-31', '1980-04-30',
#                '1980-05-31', '1980-06-30', '1980-07-31', '1980-08-31',
#                '1980-09-30', '1980-10-31',
#                ...
#                '2009-02-28', '2009-03-31', '2009-04-30', '2009-05-31',
#                '2009-06-30', '2009-07-31', '2009-08-31', '2009-09-30',
#                '2009-10-31', '2009-11-30'],
#               dtype='datetime64[ns]', name='Date', length=359, freq=None)

# %%
LogExcessReturn.columns
# Out:
# Index(['yr2', 'yr3', 'yr4', 'yr5'], dtype='object')

# %%
dfFactor = pd.read_csv(os.path.join(datapath, "dfFactor.csv"))
dfFactor = dfFactor.set_index("Date")
dfFactor.index = pd.to_datetime(dfFactor.index)
dfFactor = dfFactor.rename({"Amihud liquidity": "AmihudLiq",
                       "Mkt-RF": "MktRF",
                       "BWSENT^": "BWSENTcoth"}, axis = 1)
dfFactor.columns
# Out:
# Index(['AmihudLiq', 'AggLiq', 'InnovLiq', 'TradedLiq', 'CLI', 'MktRF', 'SMB',
#        'HML', 'RMW', 'CMA', 'RF', 'BWSENTcoth', 'BWSENT', 'RV', 'BV', 'RJ',
#        'CP'],
#       dtype='object')

# %%
pcaFactor = pd.read_csv(os.path.join(datapath, "pcaFactor.csv"))
pcaFactor = pcaFactor.set_index("Date")
pcaFactor.index = pd.to_datetime(pcaFactor.index)
pcaFactor = pcaFactor.rename({"Size/BM": "SizeBM",
                       "Prices,Yield,Dividends(PYD)": "PYD",
                       "RiskFactors(RiF)": "RiF"}, axis = 1)

# %%
pcaFactor.index
# Out:
# DatetimeIndex(['1980-01-31', '1980-02-29', '1980-03-31', '1980-04-30',
#                '1980-05-31', '1980-06-30', '1980-07-31', '1980-08-31',
#                '1980-09-30', '1980-10-31',
#                ...
#                '2009-02-28', '2009-03-31', '2009-04-30', '2009-05-31',
#                '2009-06-30', '2009-07-31', '2009-08-31', '2009-09-30',
#                '2009-10-31', '2009-11-30'],
#               dtype='datetime64[ns]', name='Date', length=359, freq=None)

# %%
pcaFactor.columns
# Out:
# Index(['CLI_allPca', 'tech_class0', 'tech_class1', 'tech_class2',
#        'tech_class3', 'tech_class4', 'tech_class5', 'tech_class6',
#        'tech_class7', 'tech_class8', 'tech_class9', 'output_and_income',
#        'labor_market', 'housing', 'consumption', 'money', 'bond_ex', 'price',
#        'stock', 'PYD', 'RiF', 'Industries', 'SizeBM'],
#       dtype='object')

# %%
Y = LogExcessReturn['yr2']

# %%
Factor = pd.concat([dfFactor, pcaFactor], axis=1)
Factor_normal, _ = minmaxscaler_for_train(Factor)

# %%
Factor_normal.columns
# Out:
# Index(['AmihudLiq', 'AggLiq', 'InnovLiq', 'TradedLiq', 'CLI', 'MktRF', 'SMB',
#        'HML', 'RMW', 'CMA', 'RF', 'BWSENTcoth', 'BWSENT', 'RV', 'BV', 'RJ',
#        'CP', 'CLI_allPca', 'tech_class0', 'tech_class1', 'tech_class2',
#        'tech_class3', 'tech_class4', 'tech_class5', 'tech_class6',
#        'tech_class7', 'tech_class8', 'tech_class9', 'output_and_income',
#        'labor_market', 'housing', 'consumption', 'money', 'bond_ex', 'price',
#        'stock', 'PYD', 'RiF', 'Industries', 'SizeBM'],
#       dtype='object')

# %%
LogExcessReturn['mean'] = LogExcessReturn.mean(axis=1)

# %% [markdown]
# ## 因子列表
#
# * 流动性：(1)AmihudLiquidity； (2)PastorandStambaughLiq
#
# * 领先指标：（1）CompositeLeadingIndicators of USA（只有美国）；（2）CompositeLeadingIndicators_8Country（8个国家PCA，描述国际CLI情况）
#
# * Fama五因子：F-F_Research_Data_5_Factors_2x3
#
# * 投资者情绪：Baker and Wurgler (2006, 2007)
#
# * 波动率跳跃：Wright J H, Zhou H
#
# * 技术指标：10类200个技术因子，各类进行PCA，最后得到10个因子，代表10类
#
# * CP因子：CP文章
#
# * 宏观因子：8类132个技术因子，各类进行PCA，最后得到8个因子，代表8类， Ludvigson and Ng (2009)
#
# * 金融指标：4类147个技术因子，各类进行PCA，最后得到4个因子，代表4类，Ludvigson and Ng (2007)
#
# * LogExcessReturn：CP文章，超额收益

# %%
type(LogExcessReturn)
# Out:
# pandas.core.frame.DataFrame

# %%
GOODFactor = pd.DataFrame(index = dfFactor.index)

# %% [markdown]
# ## 流动性

# %% [markdown]
# ### Unrestricted Model

# %%
dfFactor_normal, _ = minmaxscaler_for_train(Factor)

name = ['AmihudLiq', 'AggLiq', 'InnovLiq', 'TradedLiq']

for i in range(2, 6):
    Y = LogExcessReturn['yr' + str(i)]
    model = sm.OLS(Y, dfFactor_normal[name]).fit()
    result = model.summary()
    print(result)
    print("\n\n")
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    yr2   R-squared:                       0.180
# Model:                            OLS   Adj. R-squared:                  0.170
# Method:                 Least Squares   F-statistic:                     19.44
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           1.78e-14
# Time:                        19:10:02   Log-Likelihood:                -737.30
# No. Observations:                 359   AIC:                             1483.
# Df Residuals:                     355   BIC:                             1498.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# AmihudLiq     -1.5496      1.500     -1.033      0.302      -4.499       1.400
# AggLiq        -0.4973      1.622     -0.307      0.759      -3.687       2.693
# InnovLiq       2.2858      1.839      1.243      0.215      -1.331       5.903
# TradedLiq     -0.3135      0.813     -0.386      0.700      -1.912       1.285
# ==============================================================================
# Omnibus:                        9.054   Durbin-Watson:                   0.165
# Prob(Omnibus):                  0.011   Jarque-Bera (JB):               10.823
# Skew:                          -0.258   Prob(JB):                      0.00447
# Kurtosis:                       3.677   Cond. No.                         23.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    yr3   R-squared:                       0.147
# Model:                            OLS   Adj. R-squared:                  0.137
# Method:                 Least Squares   F-statistic:                     15.29
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           1.52e-11
# Time:                        19:10:02   Log-Likelihood:                -968.34
# No. Observations:                 359   AIC:                             1945.
# Df Residuals:                     355   BIC:                             1960.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# AmihudLiq     -2.4978      2.855     -0.875      0.382      -8.112       3.116
# AggLiq        -1.1600      3.087     -0.376      0.707      -7.231       4.911
# InnovLiq       4.2546      3.500      1.215      0.225      -2.630      11.139
# TradedLiq     -0.5850      1.547     -0.378      0.705      -3.626       2.457
# ==============================================================================
# Omnibus:                        9.593   Durbin-Watson:                   0.151
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):               10.063
# Skew:                          -0.331   Prob(JB):                      0.00653
# Kurtosis:                       3.485   Cond. No.                         23.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    yr4   R-squared:                       0.136
# Model:                            OLS   Adj. R-squared:                  0.127
# Method:                 Least Squares   F-statistic:                     14.01
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           1.27e-10
# Time:                        19:10:02   Log-Likelihood:                -1089.4
# No. Observations:                 359   AIC:                             2187.
# Df Residuals:                     355   BIC:                             2202.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# AmihudLiq     -3.2273      4.000     -0.807      0.420     -11.093       4.639
# AggLiq        -1.6933      4.325     -0.391      0.696     -10.200       6.813
# InnovLiq       5.9747      4.904      1.218      0.224      -3.671      15.620
# TradedLiq     -0.9766      2.167     -0.451      0.652      -5.238       3.285
# ==============================================================================
# Omnibus:                        6.829   Durbin-Watson:                   0.147
# Prob(Omnibus):                  0.033   Jarque-Bera (JB):                6.710
# Skew:                          -0.290   Prob(JB):                       0.0349
# Kurtosis:                       3.335   Cond. No.                         23.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    yr5   R-squared:                       0.113
# Model:                            OLS   Adj. R-squared:                  0.103
# Method:                 Least Squares   F-statistic:                     11.30
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           1.22e-08
# Time:                        19:10:02   Log-Likelihood:                -1164.0
# No. Observations:                 359   AIC:                             2336.
# Df Residuals:                     355   BIC:                             2352.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# AmihudLiq     -3.9649      4.923     -0.805      0.421     -13.648       5.718
# AggLiq        -2.7686      5.324     -0.520      0.603     -13.240       7.703
# InnovLiq       7.6183      6.037      1.262      0.208      -4.255      19.492
# TradedLiq     -1.0771      2.667     -0.404      0.687      -6.323       4.169
# ==============================================================================
# Omnibus:                        6.402   Durbin-Watson:                   0.166
# Prob(Omnibus):                  0.041   Jarque-Bera (JB):                6.220
# Skew:                          -0.285   Prob(JB):                       0.0446
# Kurtosis:                       3.302   Cond. No.                         23.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
Y = LogExcessReturn['yr5']
model = sm.OLS(Y, dfFactor_normal[name]).fit()
result = model.summary()
result
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    yr5   R-squared:                       0.113
# Model:                            OLS   Adj. R-squared:                  0.103
# Method:                 Least Squares   F-statistic:                     11.30
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           1.22e-08
# Time:                        19:10:02   Log-Likelihood:                -1164.0
# No. Observations:                 359   AIC:                             2336.
# Df Residuals:                     355   BIC:                             2352.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# AmihudLiq     -3.9649      4.923     -0.805      0.421     -13.648       5.718
# AggLiq        -2.7686      5.324     -0.520      0.603     -13.240       7.703
# InnovLiq       7.6183      6.037      1.262      0.208      -4.255      19.492
# TradedLiq     -1.0771      2.667     -0.404      0.687      -6.323       4.169
# ==============================================================================
# Omnibus:                        6.402   Durbin-Watson:                   0.166
# Prob(Omnibus):                  0.041   Jarque-Bera (JB):                6.220
# Skew:                          -0.285   Prob(JB):                       0.0446
# Kurtosis:                       3.302   Cond. No.                         23.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model.rsquared
# Out:
# 0.11292736275712212

# %% [markdown]
# ### Restricted Model

# %%
dfFactor_normal, _ = minmaxscaler_for_train(Factor)

Y = LogExcessReturn['mean']

name = ['AmihudLiq', 'AggLiq', 'InnovLiq', 'TradedLiq']

model = sm.OLS(Y, dfFactor_normal[name]).fit()
result = model.summary()
print(result)
print("\n\n")
# print(result.tables[0][0][3].data)

GOODFactor['Liq_total_minmax'] = (dfFactor_normal[name] * model.params).sum(axis=1)

for i in range(2, 6):
    Y = LogExcessReturn['yr' + str(i)]
    model = sm.OLS(Y, GOODFactor['Liq_total_minmax']).fit()
    result = model.summary()
    print(result)
    print("\n\n")
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   mean   R-squared:                       0.136
# Model:                            OLS   Adj. R-squared:                  0.126
# Method:                 Least Squares   F-statistic:                     13.96
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           1.39e-10
# Time:                        19:10:02   Log-Likelihood:                -1020.2
# No. Observations:                 359   AIC:                             2048.
# Df Residuals:                     355   BIC:                             2064.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# AmihudLiq     -2.8099      3.298     -0.852      0.395      -9.296       3.676
# AggLiq        -1.5298      3.567     -0.429      0.668      -8.544       5.485
# InnovLiq       5.0333      4.044      1.245      0.214      -2.920      12.987
# TradedLiq     -0.7381      1.787     -0.413      0.680      -4.252       2.776
# ==============================================================================
# Omnibus:                        7.452   Durbin-Watson:                   0.151
# Prob(Omnibus):                  0.024   Jarque-Bera (JB):                7.433
# Skew:                          -0.299   Prob(JB):                       0.0243
# Kurtosis:                       3.373   Cond. No.                         23.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    yr2   R-squared:                       0.180
# Model:                            OLS   Adj. R-squared:                  0.177
# Method:                 Least Squares   F-statistic:                     78.33
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           4.08e-17
# Time:                        19:10:02   Log-Likelihood:                -737.33
# No. Observations:                 359   AIC:                             1477.
# Df Residuals:                     358   BIC:                             1481.
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Liq_total_minmax     0.5365      0.061      8.850      0.000       0.417       0.656
# ==============================================================================
# Omnibus:                        9.042   Durbin-Watson:                   0.167
# Prob(Omnibus):                  0.011   Jarque-Bera (JB):               10.823
# Skew:                          -0.257   Prob(JB):                      0.00446
# Kurtosis:                       3.678   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    yr3   R-squared:                       0.147
# Model:                            OLS   Adj. R-squared:                  0.145
# Method:                 Least Squares   F-statistic:                     61.66
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           4.80e-14
# Time:                        19:10:02   Log-Likelihood:                -968.35
# No. Observations:                 359   AIC:                             1939.
# Df Residuals:                     358   BIC:                             1943.
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Liq_total_minmax     0.9058      0.115      7.852      0.000       0.679       1.133
# ==============================================================================
# Omnibus:                        9.593   Durbin-Watson:                   0.152
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):               10.063
# Skew:                          -0.331   Prob(JB):                      0.00653
# Kurtosis:                       3.485   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    yr4   R-squared:                       0.136
# Model:                            OLS   Adj. R-squared:                  0.134
# Method:                 Least Squares   F-statistic:                     56.49
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           4.57e-13
# Time:                        19:10:02   Log-Likelihood:                -1089.4
# No. Observations:                 359   AIC:                             2181.
# Df Residuals:                     358   BIC:                             2185.
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Liq_total_minmax     1.2148      0.162      7.516      0.000       0.897       1.533
# ==============================================================================
# Omnibus:                        6.880   Durbin-Watson:                   0.147
# Prob(Omnibus):                  0.032   Jarque-Bera (JB):                6.768
# Skew:                          -0.291   Prob(JB):                       0.0339
# Kurtosis:                       3.338   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    yr5   R-squared:                       0.113
# Model:                            OLS   Adj. R-squared:                  0.110
# Method:                 Least Squares   F-statistic:                     45.55
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           6.01e-11
# Time:                        19:10:02   Log-Likelihood:                -1164.0
# No. Observations:                 359   AIC:                             2330.
# Df Residuals:                     358   BIC:                             2334.
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Liq_total_minmax     1.3429      0.199      6.749      0.000       0.952       1.734
# ==============================================================================
# Omnibus:                        6.380   Durbin-Watson:                   0.164
# Prob(Omnibus):                  0.041   Jarque-Bera (JB):                6.195
# Skew:                          -0.285   Prob(JB):                       0.0452
# Kurtosis:                       3.300   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
def get_coef_table(model,i):
    coef_name = model.params.index[0]
    df_coef = pd.DataFrame({'coef Name': [coef_name],
                            'coef.':[round(model.params[coef_name],2)],
                        'std err':[round(model.bse[coef_name],2)],
                        'pvalue':[round(model.pvalues[coef_name],2)],
                        '[ 0.025':[round(model.conf_int(alpha=0.05, cols=None)[0][coef_name],2)],
                        '0.975 ]':[round(model.conf_int(alpha=0.05, cols=None)[1][coef_name],2)],
                        'R-sqaured':[round(model.rsquared,2)]
                        },index = ['yr'+str(i)])
    return df_coef
#df = get_coef_table(model,2)
#pd.DataFrame().append(df)

# %%
result = pd.DataFrame()
for i in range(2, 6):
    Y = LogExcessReturn['yr' + str(i)]
    model = sm.OLS(Y, GOODFactor['Liq_total_minmax']).fit()
    df = get_coef_table(model,i)
    #result = model.summary()
    #print(result)
    result = result.append(df)
result
# Out:
#             coef Name  coef.  std err  pvalue  [ 0.025  0.975 ]  R-sqaured
# yr2  Liq_total_minmax   0.54     0.06     0.0     0.42     0.66       0.18
# yr3  Liq_total_minmax   0.91     0.12     0.0     0.68     1.13       0.15
# yr4  Liq_total_minmax   1.21     0.16     0.0     0.90     1.53       0.14
# yr5  Liq_total_minmax   1.34     0.20     0.0     0.95     1.73       0.11

# %%
type(model)
model.bse
# Out:
# Liq_total_minmax    0.19897
# dtype: float64

# %% [markdown]
# ## CLI

# %% [markdown]
# ### Unrestricted Model

# %%
dfFactor_normal, _ = minmaxscaler_for_train(Factor)

name = ['CLI', 'CLI_allPca']

for i in range(2, 6):
    Y = LogExcessReturn['yr' + str(i)]
    model = sm.OLS(Y, dfFactor_normal[name]).fit()
    result = model.summary()
    print(result)
    print("\n\n")
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    yr2   R-squared:                       0.285
# Model:                            OLS   Adj. R-squared:                  0.281
# Method:                 Least Squares   F-statistic:                     71.15
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           9.86e-27
# Time:                        19:13:03   Log-Likelihood:                -712.63
# No. Observations:                 359   AIC:                             1429.
# Df Residuals:                     357   BIC:                             1437.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# CLI           -0.2483      0.199     -1.246      0.214      -0.640       0.144
# CLI_allPca     3.6505      0.401      9.098      0.000       2.861       4.440
# ==============================================================================
# Omnibus:                       36.926   Durbin-Watson:                   0.165
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               75.993
# Skew:                          -0.564   Prob(JB):                     3.15e-17
# Kurtosis:                       4.952   Cond. No.                         3.33
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    yr3   R-squared:                       0.248
# Model:                            OLS   Adj. R-squared:                  0.244
# Method:                 Least Squares   F-statistic:                     58.94
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           7.62e-23
# Time:                        19:13:03   Log-Likelihood:                -945.66
# No. Observations:                 359   AIC:                             1895.
# Df Residuals:                     357   BIC:                             1903.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# CLI           -0.5674      0.382     -1.487      0.138      -1.318       0.183
# CLI_allPca     6.5320      0.768      8.506      0.000       5.022       8.042
# ==============================================================================
# Omnibus:                       37.123   Durbin-Watson:                   0.150
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               62.442
# Skew:                          -0.638   Prob(JB):                     2.76e-14
# Kurtosis:                       4.595   Cond. No.                         3.33
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    yr4   R-squared:                       0.232
# Model:                            OLS   Adj. R-squared:                  0.228
# Method:                 Least Squares   F-statistic:                     54.02
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           3.19e-21
# Time:                        19:13:03   Log-Likelihood:                -1068.3
# No. Observations:                 359   AIC:                             2141.
# Df Residuals:                     357   BIC:                             2148.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# CLI           -0.7827      0.537     -1.458      0.146      -1.838       0.273
# CLI_allPca     8.8225      1.081      8.165      0.000       6.697      10.947
# ==============================================================================
# Omnibus:                       29.645   Durbin-Watson:                   0.146
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               44.907
# Skew:                          -0.563   Prob(JB):                     1.77e-10
# Kurtosis:                       4.317   Cond. No.                         3.33
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    yr5   R-squared:                       0.205
# Model:                            OLS   Adj. R-squared:                  0.201
# Method:                 Least Squares   F-statistic:                     46.13
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           1.52e-18
# Time:                        19:13:03   Log-Likelihood:                -1144.3
# No. Observations:                 359   AIC:                             2293.
# Df Residuals:                     357   BIC:                             2300.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# CLI           -1.1432      0.663     -1.723      0.086      -2.448       0.162
# CLI_allPca    10.3819      1.335      7.775      0.000       7.756      13.008
# ==============================================================================
# Omnibus:                       27.375   Durbin-Watson:                   0.167
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               40.522
# Skew:                          -0.535   Prob(JB):                     1.59e-09
# Kurtosis:                       4.250   Cond. No.                         3.33
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Restricted Model

# %%
dfFactor_normal, _ = minmaxscaler_for_train(Factor)

Y = LogExcessReturn['mean']

name = ['CLI', 'CLI_allPca']

model = sm.OLS(Y, dfFactor_normal[name]).fit()
result = model.summary()
print(result)
print("\n\n")
# print(result.tables[0][0][3].data)

GOODFactor['CLI_minmax'] = (dfFactor_normal[name] * model.params).sum(axis=1)

for i in range(2, 6):
    Y = LogExcessReturn['yr' + str(i)]
    model = sm.OLS(Y, GOODFactor['CLI_minmax']).fit()
    result = model.summary()
    print(result)
    print("\n\n")
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   mean   R-squared:                       0.234
# Model:                            OLS   Adj. R-squared:                  0.230
# Method:                 Least Squares   F-statistic:                     54.53
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           2.17e-21
# Time:                        19:13:04   Log-Likelihood:                -998.56
# No. Observations:                 359   AIC:                             2001.
# Df Residuals:                     357   BIC:                             2009.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# CLI           -0.6854      0.442     -1.550      0.122      -1.555       0.184
# CLI_allPca     7.3467      0.890      8.256      0.000       5.597       9.097
# ==============================================================================
# Omnibus:                       31.570   Durbin-Watson:                   0.150
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               49.935
# Skew:                          -0.577   Prob(JB):                     1.43e-11
# Kurtosis:                       4.417   Cond. No.                         3.33
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    yr2   R-squared:                       0.284
# Model:                            OLS   Adj. R-squared:                  0.282
# Method:                 Least Squares   F-statistic:                     142.3
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           7.53e-28
# Time:                        19:13:04   Log-Likelihood:                -712.77
# No. Observations:                 359   AIC:                             1428.
# Df Residuals:                     358   BIC:                             1431.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# CLI_minmax     0.5146      0.043     11.929      0.000       0.430       0.599
# ==============================================================================
# Omnibus:                       38.543   Durbin-Watson:                   0.165
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               80.121
# Skew:                          -0.583   Prob(JB):                     4.00e-18
# Kurtosis:                       4.999   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    yr3   R-squared:                       0.248
# Model:                            OLS   Adj. R-squared:                  0.246
# Method:                 Least Squares   F-statistic:                     118.2
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           5.58e-24
# Time:                        19:13:04   Log-Likelihood:                -945.67
# No. Observations:                 359   AIC:                             1893.
# Df Residuals:                     358   BIC:                             1897.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# CLI_minmax     0.8972      0.083     10.871      0.000       0.735       1.059
# ==============================================================================
# Omnibus:                       37.516   Durbin-Watson:                   0.150
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               63.322
# Skew:                          -0.643   Prob(JB):                     1.78e-14
# Kurtosis:                       4.607   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    yr4   R-squared:                       0.232
# Model:                            OLS   Adj. R-squared:                  0.230
# Method:                 Least Squares   F-statistic:                     108.3
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           2.43e-22
# Time:                        19:13:04   Log-Likelihood:                -1068.3
# No. Observations:                 359   AIC:                             2139.
# Df Residuals:                     358   BIC:                             2142.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# CLI_minmax     1.2086      0.116     10.408      0.000       0.980       1.437
# ==============================================================================
# Omnibus:                       29.877   Durbin-Watson:                   0.146
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               45.361
# Skew:                          -0.566   Prob(JB):                     1.41e-10
# Kurtosis:                       4.324   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    yr5   R-squared:                       0.205
# Model:                            OLS   Adj. R-squared:                  0.203
# Method:                 Least Squares   F-statistic:                     92.40
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           1.30e-19
# Time:                        19:13:04   Log-Likelihood:                -1144.3
# No. Observations:                 359   AIC:                             2291.
# Df Residuals:                     358   BIC:                             2295.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# CLI_minmax     1.3796      0.144      9.613      0.000       1.097       1.662
# ==============================================================================
# Omnibus:                       26.622   Durbin-Watson:                   0.167
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               39.065
# Skew:                          -0.526   Prob(JB):                     3.29e-09
# Kurtosis:                       4.227   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
result = pd.DataFrame()
for i in range(2, 6):
    Y = LogExcessReturn['yr' + str(i)]
    model = sm.OLS(Y, GOODFactor['CLI_minmax']).fit()
    df = get_coef_table(model,i)
    #result = model.summary()
    #print(result)
    result = result.append(df)
result
# Out:
#       coef Name  coef.  std err  pvalue  [ 0.025  0.975 ]  R-sqaured
# yr2  CLI_minmax   0.51     0.04     0.0     0.43     0.60       0.28
# yr3  CLI_minmax   0.90     0.08     0.0     0.73     1.06       0.25
# yr4  CLI_minmax   1.21     0.12     0.0     0.98     1.44       0.23
# yr5  CLI_minmax   1.38     0.14     0.0     1.10     1.66       0.21

# %% [markdown]
# ## Fama五因子

# %% [markdown]
# ### Unrestricted Model

# %%
dfFactor_normal, _ = minmaxscaler_for_train(Factor)

name = ['MktRF','SMB', 'HML', 'RMW', 'CMA', 'RF']

for i in range(2, 6):
    Y = LogExcessReturn['yr' + str(i)]
    model = sm.OLS(Y, dfFactor_normal[name]).fit()
    result = model.summary()
    print(result)
    print("\n\n")

# %% [markdown]
# ### Restricted Model

# %%
dfFactor_normal, _ = minmaxscaler_for_train(Factor)

Y = LogExcessReturn['mean']

name = ['MktRF','SMB', 'HML', 'RMW', 'CMA', 'RF']

model = sm.OLS(Y, dfFactor_normal[name]).fit()
result = model.summary()
print(result)
print("\n\n")
# print(result.tables[0][0][3].data)

GOODFactor['FF5_total_minmax'] = (dfFactor_normal[name] * model.params).sum(axis=1)

for i in range(2, 6):
    Y = LogExcessReturn['yr' + str(i)]
    model = sm.OLS(Y, GOODFactor['FF5_total_minmax']).fit()
    result = model.summary()
    print(result)
    print("\n\n")

# %%
result = pd.DataFrame()
for i in range(2, 6):
    Y = LogExcessReturn['yr' + str(i)]
    model = sm.OLS(Y, GOODFactor['FF5_total_minmax']).fit()
    df = get_coef_table(model,i)
    #result = model.summary()
    #print(result)
    result = result.append(df)
result

# %% [markdown]
# ## 投资者情绪

# %% [markdown]
# ### Unrestricted Model

# %%
dfFactor_normal, _ = minmaxscaler_for_train(Factor)

name = ['BWSENTcoth', 'BWSENT']

for i in range(2, 6):
    Y = LogExcessReturn['yr' + str(i)]
    model = sm.OLS(Y, dfFactor_normal[name]).fit()
    result = model.summary()
    print(result)
    print("\n\n")
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    yr2   R-squared:                       0.207
# Model:                            OLS   Adj. R-squared:                  0.202
# Method:                 Least Squares   F-statistic:                     46.54
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           1.09e-18
# Time:                        19:14:55   Log-Likelihood:                -731.26
# No. Observations:                 359   AIC:                             1467.
# Df Residuals:                     357   BIC:                             1474.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# BWSENTcoth    -7.2168      1.845     -3.911      0.000     -10.845      -3.588
# BWSENT         8.6904      1.673      5.194      0.000       5.400      11.981
# ==============================================================================
# Omnibus:                       28.244   Durbin-Watson:                   0.159
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               35.310
# Skew:                          -0.625   Prob(JB):                     2.15e-08
# Kurtosis:                       3.894   Cond. No.                         13.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    yr3   R-squared:                       0.153
# Model:                            OLS   Adj. R-squared:                  0.148
# Method:                 Least Squares   F-statistic:                     32.28
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           1.30e-13
# Time:                        19:14:55   Log-Likelihood:                -967.04
# No. Observations:                 359   AIC:                             1938.
# Df Residuals:                     357   BIC:                             1946.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# BWSENTcoth   -11.0617      3.558     -3.109      0.002     -18.060      -4.063
# BWSENT        13.5143      3.227      4.188      0.000       7.168      19.861
# ==============================================================================
# Omnibus:                       25.777   Durbin-Watson:                   0.140
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               29.907
# Skew:                          -0.629   Prob(JB):                     3.20e-07
# Kurtosis:                       3.644   Cond. No.                         13.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    yr4   R-squared:                       0.128
# Model:                            OLS   Adj. R-squared:                  0.123
# Method:                 Least Squares   F-statistic:                     26.25
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           2.31e-11
# Time:                        19:14:55   Log-Likelihood:                -1091.1
# No. Observations:                 359   AIC:                             2186.
# Df Residuals:                     357   BIC:                             2194.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# BWSENTcoth   -12.7166      5.027     -2.529      0.012     -22.604      -2.830
# BWSENT        16.0585      4.559      3.522      0.000       7.092      25.025
# ==============================================================================
# Omnibus:                       18.819   Durbin-Watson:                   0.135
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               20.406
# Skew:                          -0.539   Prob(JB):                     3.70e-05
# Kurtosis:                       3.450   Cond. No.                         13.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    yr5   R-squared:                       0.102
# Model:                            OLS   Adj. R-squared:                  0.097
# Method:                 Least Squares   F-statistic:                     20.26
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           4.63e-09
# Time:                        19:14:55   Log-Likelihood:                -1166.2
# No. Observations:                 359   AIC:                             2336.
# Df Residuals:                     357   BIC:                             2344.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# BWSENTcoth   -13.7317      6.198     -2.216      0.027     -25.921      -1.543
# BWSENT        17.3574      5.621      3.088      0.002       6.304      28.411
# ==============================================================================
# Omnibus:                       17.142   Durbin-Watson:                   0.155
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               18.334
# Skew:                          -0.512   Prob(JB):                     0.000104
# Kurtosis:                       3.423   Cond. No.                         13.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Restricted Model

# %%
dfFactor_normal, _ = minmaxscaler_for_train(Factor)

Y = LogExcessReturn['mean']

name = ['BWSENTcoth', 'BWSENT']

model = sm.OLS(Y, dfFactor_normal[name]).fit()
result = model.summary()
print(result)
print("\n\n")
# print(result.tables[0][0][3].data)

GOODFactor['BWaggSENT_minmax'] = (dfFactor_normal[name] * model.params).sum(axis=1)

for i in range(2, 6):
    Y = LogExcessReturn['yr' + str(i)]
    model = sm.OLS(Y, GOODFactor['BWaggSENT_minmax']).fit()
    result = model.summary()
    print(result)
    print("\n\n")
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   mean   R-squared:                       0.133
# Model:                            OLS   Adj. R-squared:                  0.128
# Method:                 Least Squares   F-statistic:                     27.32
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           9.08e-12
# Time:                        19:14:58   Log-Likelihood:                -1020.8
# No. Observations:                 359   AIC:                             2046.
# Df Residuals:                     357   BIC:                             2053.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# BWSENTcoth   -11.1817      4.134     -2.705      0.007     -19.311      -3.052
# BWSENT        13.9052      3.749      3.709      0.000       6.533      21.277
# ==============================================================================
# Omnibus:                       20.828   Durbin-Watson:                   0.140
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               23.035
# Skew:                          -0.566   Prob(JB):                     9.95e-06
# Kurtosis:                       3.510   Cond. No.                         13.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    yr2   R-squared:                       0.206
# Model:                            OLS   Adj. R-squared:                  0.204
# Method:                 Least Squares   F-statistic:                     93.13
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           9.74e-20
# Time:                        19:14:58   Log-Likelihood:                -731.34
# No. Observations:                 359   AIC:                             1465.
# Df Residuals:                     358   BIC:                             1469.
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# BWaggSENT_minmax     0.5820      0.060      9.650      0.000       0.463       0.701
# ==============================================================================
# Omnibus:                       26.276   Durbin-Watson:                   0.158
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               32.291
# Skew:                          -0.599   Prob(JB):                     9.73e-08
# Kurtosis:                       3.851   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    yr3   R-squared:                       0.153
# Model:                            OLS   Adj. R-squared:                  0.151
# Method:                 Least Squares   F-statistic:                     64.70
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           1.29e-14
# Time:                        19:14:58   Log-Likelihood:                -967.06
# No. Observations:                 359   AIC:                             1936.
# Df Residuals:                     358   BIC:                             1940.
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# BWaggSENT_minmax     0.9353      0.116      8.043      0.000       0.707       1.164
# ==============================================================================
# Omnibus:                       24.946   Durbin-Watson:                   0.140
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               28.742
# Skew:                          -0.618   Prob(JB):                     5.74e-07
# Kurtosis:                       3.628   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    yr4   R-squared:                       0.128
# Model:                            OLS   Adj. R-squared:                  0.126
# Method:                 Least Squares   F-statistic:                     52.63
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           2.52e-12
# Time:                        19:14:58   Log-Likelihood:                -1091.1
# No. Observations:                 359   AIC:                             2184.
# Df Residuals:                     358   BIC:                             2188.
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# BWaggSENT_minmax     1.1918      0.164      7.255      0.000       0.869       1.515
# ==============================================================================
# Omnibus:                       19.338   Durbin-Watson:                   0.135
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               21.060
# Skew:                          -0.547   Prob(JB):                     2.67e-05
# Kurtosis:                       3.460   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    yr5   R-squared:                       0.102
# Model:                            OLS   Adj. R-squared:                  0.099
# Method:                 Least Squares   F-statistic:                     40.62
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           5.71e-10
# Time:                        19:14:58   Log-Likelihood:                -1166.3
# No. Observations:                 359   AIC:                             2335.
# Df Residuals:                     358   BIC:                             2338.
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# BWaggSENT_minmax     1.2908      0.203      6.373      0.000       0.892       1.689
# ==============================================================================
# Omnibus:                       17.612   Durbin-Watson:                   0.155
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               18.913
# Skew:                          -0.519   Prob(JB):                     7.82e-05
# Kurtosis:                       3.432   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
result = pd.DataFrame()
for i in range(2, 6):
    Y = LogExcessReturn['yr' + str(i)]
    model = sm.OLS(Y, GOODFactor['BWaggSENT_minmax']).fit()
    df = get_coef_table(model,i)
    #result = model.summary()
    #print(result)
    result = result.append(df)
result
# Out:
#             coef Name  coef.  std err  pvalue  [ 0.025  0.975 ]  R-sqaured
# yr2  BWaggSENT_minmax   0.58     0.06     0.0     0.46     0.70       0.21
# yr3  BWaggSENT_minmax   0.94     0.12     0.0     0.71     1.16       0.15
# yr4  BWaggSENT_minmax   1.19     0.16     0.0     0.87     1.51       0.13
# yr5  BWaggSENT_minmax   1.29     0.20     0.0     0.89     1.69       0.10

# %% [markdown]
# ## 波动率跳跃

# %% [markdown]
# ### Unrestricted Model

# %%
dfFactor_normal, _ = minmaxscaler_for_train(Factor)

name = ['RV', 'BV', 'RJ']

for i in range(2, 6):
    Y = LogExcessReturn['yr' + str(i)]
    model = sm.OLS(Y, dfFactor_normal[name]).fit()
    result = model.summary()
    print(result)
    print("\n\n")
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    yr2   R-squared:                       0.165
# Model:                            OLS   Adj. R-squared:                  0.158
# Method:                 Least Squares   F-statistic:                     23.52
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           6.57e-14
# Time:                        19:20:28   Log-Likelihood:                -740.39
# No. Observations:                 359   AIC:                             1487.
# Df Residuals:                     356   BIC:                             1498.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# RV            -4.6131      2.031     -2.271      0.024      -8.607      -0.619
# BV             0.3532      0.738      0.478      0.633      -1.099       1.805
# RJ             2.3397      0.308      7.585      0.000       1.733       2.946
# ==============================================================================
# Omnibus:                        5.162   Durbin-Watson:                   0.203
# Prob(Omnibus):                  0.076   Jarque-Bera (JB):                5.970
# Skew:                          -0.147   Prob(JB):                       0.0506
# Kurtosis:                       3.559   Cond. No.                         8.57
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    yr3   R-squared:                       0.145
# Model:                            OLS   Adj. R-squared:                  0.137
# Method:                 Least Squares   F-statistic:                     20.06
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           4.91e-12
# Time:                        19:20:28   Log-Likelihood:                -968.84
# No. Observations:                 359   AIC:                             1944.
# Df Residuals:                     356   BIC:                             1955.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# RV            -8.7570      3.838     -2.282      0.023     -16.304      -1.210
# BV            -0.1353      1.395     -0.097      0.923      -2.878       2.608
# RJ             4.2537      0.583      7.299      0.000       3.108       5.400
# ==============================================================================
# Omnibus:                        2.475   Durbin-Watson:                   0.187
# Prob(Omnibus):                  0.290   Jarque-Bera (JB):                2.252
# Skew:                          -0.131   Prob(JB):                        0.324
# Kurtosis:                       3.286   Cond. No.                         8.57
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    yr4   R-squared:                       0.140
# Model:                            OLS   Adj. R-squared:                  0.133
# Method:                 Least Squares   F-statistic:                     19.30
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           1.29e-11
# Time:                        19:20:28   Log-Likelihood:                -1088.7
# No. Observations:                 359   AIC:                             2183.
# Df Residuals:                     356   BIC:                             2195.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# RV           -12.3629      5.358     -2.307      0.022     -22.901      -1.825
# BV            -0.6747      1.948     -0.346      0.729      -4.505       3.156
# RJ             5.9130      0.814      7.266      0.000       4.313       7.513
# ==============================================================================
# Omnibus:                        1.007   Durbin-Watson:                   0.185
# Prob(Omnibus):                  0.604   Jarque-Bera (JB):                0.767
# Skew:                          -0.054   Prob(JB):                        0.681
# Kurtosis:                       3.200   Cond. No.                         8.57
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    yr5   R-squared:                       0.124
# Model:                            OLS   Adj. R-squared:                  0.116
# Method:                 Least Squares   F-statistic:                     16.75
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           3.37e-10
# Time:                        19:20:28   Log-Likelihood:                -1161.8
# No. Observations:                 359   AIC:                             2330.
# Df Residuals:                     356   BIC:                             2341.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# RV           -15.5580      6.570     -2.368      0.018     -28.478      -2.638
# BV            -1.2087      2.388     -0.506      0.613      -5.905       3.487
# RJ             6.8334      0.998      6.849      0.000       4.871       8.796
# ==============================================================================
# Omnibus:                        0.816   Durbin-Watson:                   0.204
# Prob(Omnibus):                  0.665   Jarque-Bera (JB):                0.583
# Skew:                          -0.019   Prob(JB):                        0.747
# Kurtosis:                       3.194   Cond. No.                         8.57
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Restricted Model

# %%
dfFactor_normal, _ = minmaxscaler_for_train(Factor)

Y = LogExcessReturn['mean']

name = ['RV', 'BV', 'RJ']

model = sm.OLS(Y, dfFactor_normal[name]).fit()
result = model.summary()
print(result)
print("\n\n")
# print(result.tables[0][0][3].data)

GOODFactor['RJ_total_minmax'] = (dfFactor_normal[name] * model.params).sum(axis=1)

for i in range(2, 6):
    Y = LogExcessReturn['yr' + str(i)]
    model = sm.OLS(Y, GOODFactor['RJ_total_minmax']).fit()
    result = model.summary()
    print(result)
    print("\n\n")
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   mean   R-squared:                       0.139
# Model:                            OLS   Adj. R-squared:                  0.131
# Method:                 Least Squares   F-statistic:                     19.09
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           1.67e-11
# Time:                        19:20:34   Log-Likelihood:                -1019.6
# No. Observations:                 359   AIC:                             2045.
# Df Residuals:                     356   BIC:                             2057.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# RV           -10.3227      4.421     -2.335      0.020     -19.017      -1.629
# BV            -0.4164      1.607     -0.259      0.796      -3.576       2.744
# RJ             4.8350      0.671      7.202      0.000       3.515       6.155
# ==============================================================================
# Omnibus:                        1.289   Durbin-Watson:                   0.189
# Prob(Omnibus):                  0.525   Jarque-Bera (JB):                1.045
# Skew:                          -0.072   Prob(JB):                        0.593
# Kurtosis:                       3.222   Cond. No.                         8.57
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    yr2   R-squared:                       0.162
# Model:                            OLS   Adj. R-squared:                  0.159
# Method:                 Least Squares   F-statistic:                     69.12
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           1.95e-15
# Time:                        19:20:34   Log-Likelihood:                -741.16
# No. Observations:                 359   AIC:                             1484.
# Df Residuals:                     358   BIC:                             1488.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# RJ_total_minmax     0.5043      0.061      8.314      0.000       0.385       0.624
# ==============================================================================
# Omnibus:                        2.805   Durbin-Watson:                   0.221
# Prob(Omnibus):                  0.246   Jarque-Bera (JB):                2.976
# Skew:                          -0.053   Prob(JB):                        0.226
# Kurtosis:                       3.433   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    yr3   R-squared:                       0.144
# Model:                            OLS   Adj. R-squared:                  0.142
# Method:                 Least Squares   F-statistic:                     60.40
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           8.29e-14
# Time:                        19:20:34   Log-Likelihood:                -968.89
# No. Observations:                 359   AIC:                             1940.
# Df Residuals:                     358   BIC:                             1944.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# RJ_total_minmax     0.8890      0.114      7.772      0.000       0.664       1.114
# ==============================================================================
# Omnibus:                        1.908   Durbin-Watson:                   0.192
# Prob(Omnibus):                  0.385   Jarque-Bera (JB):                1.670
# Skew:                          -0.106   Prob(JB):                        0.434
# Kurtosis:                       3.259   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    yr4   R-squared:                       0.140
# Model:                            OLS   Adj. R-squared:                  0.137
# Method:                 Least Squares   F-statistic:                     58.22
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           2.15e-13
# Time:                        19:20:34   Log-Likelihood:                -1088.7
# No. Observations:                 359   AIC:                             2179.
# Df Residuals:                     358   BIC:                             2183.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# RJ_total_minmax     1.2186      0.160      7.630      0.000       0.904       1.533
# ==============================================================================
# Omnibus:                        1.069   Durbin-Watson:                   0.185
# Prob(Omnibus):                  0.586   Jarque-Bera (JB):                0.828
# Skew:                          -0.061   Prob(JB):                        0.661
# Kurtosis:                       3.202   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    yr5   R-squared:                       0.123
# Model:                            OLS   Adj. R-squared:                  0.121
# Method:                 Least Squares   F-statistic:                     50.21
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           7.38e-12
# Time:                        19:20:34   Log-Likelihood:                -1162.0
# No. Observations:                 359   AIC:                             2326.
# Df Residuals:                     358   BIC:                             2330.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# RJ_total_minmax     1.3881      0.196      7.086      0.000       1.003       1.773
# ==============================================================================
# Omnibus:                        1.108   Durbin-Watson:                   0.196
# Prob(Omnibus):                  0.575   Jarque-Bera (JB):                0.866
# Skew:                          -0.061   Prob(JB):                        0.649
# Kurtosis:                       3.208   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
result = pd.DataFrame()
for i in range(2, 6):
    Y = LogExcessReturn['yr' + str(i)]
    model = sm.OLS(Y, GOODFactor['RJ_total_minmax']).fit()
    df = get_coef_table(model,i)
    #result = model.summary()
    #print(result)
    result = result.append(df)
result
# Out:
#            coef Name  coef.  std err  pvalue  [ 0.025  0.975 ]  R-sqaured
# yr2  RJ_total_minmax   0.50     0.06     0.0     0.39     0.62       0.16
# yr3  RJ_total_minmax   0.89     0.11     0.0     0.66     1.11       0.14
# yr4  RJ_total_minmax   1.22     0.16     0.0     0.90     1.53       0.14
# yr5  RJ_total_minmax   1.39     0.20     0.0     1.00     1.77       0.12

# %% [markdown]
# ## 技术指标

# %% [markdown]
# ### Unrestricted Model

# %%
dfFactor_normal, _ = minmaxscaler_for_train(Factor)

name = [
    'tech_class0', 'tech_class1', 'tech_class2',
       'tech_class3', 'tech_class4', 'tech_class5', 'tech_class6',
       'tech_class7', 'tech_class8', 'tech_class9'
]

for i in range(2, 6):
    Y = LogExcessReturn['yr' + str(i)]
    model = sm.OLS(Y, dfFactor_normal[name]).fit()
    result = model.summary()
    print(result)
    print("\n\n")
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    yr2   R-squared:                       0.208
# Model:                            OLS   Adj. R-squared:                  0.185
# Method:                 Least Squares   F-statistic:                     9.155
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           1.85e-13
# Time:                        19:23:30   Log-Likelihood:                -731.03
# No. Observations:                 359   AIC:                             1482.
# Df Residuals:                     349   BIC:                             1521.
# Df Model:                          10
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# tech_class0   -47.3179     39.301     -1.204      0.229    -124.615      29.980
# tech_class1    26.5199     21.842      1.214      0.226     -16.439      69.478
# tech_class2    -5.5828      3.174     -1.759      0.079     -11.825       0.659
# tech_class3     0.8988      0.909      0.989      0.323      -0.889       2.686
# tech_class4    17.0650     22.002      0.776      0.438     -26.208      60.338
# tech_class5     2.9465      1.867      1.578      0.115      -0.725       6.618
# tech_class6    -0.7690      1.444     -0.533      0.595      -3.609       2.071
# tech_class7     8.1640      3.135      2.604      0.010       1.997      14.331
# tech_class8     1.1748      1.065      1.103      0.271      -0.919       3.269
# tech_class9    -0.0890      1.570     -0.057      0.955      -3.176       2.998
# ==============================================================================
# Omnibus:                       14.087   Durbin-Watson:                   0.169
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               21.166
# Skew:                          -0.288   Prob(JB):                     2.53e-05
# Kurtosis:                       4.041   Cond. No.                         543.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    yr3   R-squared:                       0.181
# Model:                            OLS   Adj. R-squared:                  0.157
# Method:                 Least Squares   F-statistic:                     7.692
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           3.89e-11
# Time:                        19:23:30   Log-Likelihood:                -961.12
# No. Observations:                 359   AIC:                             1942.
# Df Residuals:                     349   BIC:                             1981.
# Df Model:                          10
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# tech_class0   -65.4299     74.603     -0.877      0.381    -212.158      81.298
# tech_class1    40.1390     41.461      0.968      0.334     -41.406     121.684
# tech_class2    -9.2648      6.024     -1.538      0.125     -21.113       2.584
# tech_class3     0.9744      1.725      0.565      0.573      -2.419       4.367
# tech_class4    18.3505     41.764      0.439      0.661     -63.791     100.492
# tech_class5     6.8095      3.544      1.922      0.055      -0.160      13.779
# tech_class6    -2.1565      2.741     -0.787      0.432      -7.547       3.234
# tech_class7    14.0594      5.952      2.362      0.019       2.354      25.765
# tech_class8     2.0297      2.021      1.004      0.316      -1.945       6.004
# tech_class9     0.6469      2.980      0.217      0.828      -5.213       6.507
# ==============================================================================
# Omnibus:                       10.320   Durbin-Watson:                   0.150
# Prob(Omnibus):                  0.006   Jarque-Bera (JB):               12.878
# Skew:                          -0.273   Prob(JB):                      0.00160
# Kurtosis:                       3.750   Cond. No.                         543.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    yr4   R-squared:                       0.169
# Model:                            OLS   Adj. R-squared:                  0.146
# Method:                 Least Squares   F-statistic:                     7.115
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           3.27e-10
# Time:                        19:23:30   Log-Likelihood:                -1082.4
# No. Observations:                 359   AIC:                             2185.
# Df Residuals:                     349   BIC:                             2224.
# Df Model:                          10
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# tech_class0   -75.9404    104.592     -0.726      0.468    -281.651     129.770
# tech_class1    52.8821     58.128      0.910      0.364     -61.442     167.207
# tech_class2   -11.4493      8.446     -1.356      0.176     -28.061       5.162
# tech_class3     0.9116      2.419      0.377      0.706      -3.846       5.669
# tech_class4    13.5945     58.553      0.232      0.817    -101.567     128.756
# tech_class5    10.0438      4.968      2.022      0.044       0.272      19.815
# tech_class6    -3.2092      3.842     -0.835      0.404     -10.766       4.348
# tech_class7    17.6771      8.344      2.118      0.035       1.266      34.088
# tech_class8     2.9904      2.833      1.055      0.292      -2.582       8.563
# tech_class9     1.0982      4.177      0.263      0.793      -7.118       9.314
# ==============================================================================
# Omnibus:                        6.484   Durbin-Watson:                   0.146
# Prob(Omnibus):                  0.039   Jarque-Bera (JB):                7.339
# Skew:                          -0.205   Prob(JB):                       0.0255
# Kurtosis:                       3.568   Cond. No.                         543.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    yr5   R-squared:                       0.150
# Model:                            OLS   Adj. R-squared:                  0.126
# Method:                 Least Squares   F-statistic:                     6.175
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           1.07e-08
# Time:                        19:23:30   Log-Likelihood:                -1156.3
# No. Observations:                 359   AIC:                             2333.
# Df Residuals:                     349   BIC:                             2371.
# Df Model:                          10
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# tech_class0   -82.3152    128.490     -0.641      0.522    -335.027     170.397
# tech_class1    57.9897     71.409      0.812      0.417     -82.456     198.435
# tech_class2   -14.6769     10.376     -1.415      0.158     -35.084       5.730
# tech_class3     0.6847      2.971      0.230      0.818      -5.159       6.529
# tech_class4    12.6715     71.931      0.176      0.860    -128.802     154.145
# tech_class5    13.2832      6.103      2.176      0.030       1.279      25.287
# tech_class6    -4.3420      4.720     -0.920      0.358     -13.625       4.942
# tech_class7    21.7812     10.251      2.125      0.034       1.620      41.942
# tech_class8     3.3346      3.481      0.958      0.339      -3.511      10.180
# tech_class9     1.7474      5.132      0.341      0.734      -8.346      11.840
# ==============================================================================
# Omnibus:                        5.510   Durbin-Watson:                   0.166
# Prob(Omnibus):                  0.064   Jarque-Bera (JB):                6.224
# Skew:                          -0.172   Prob(JB):                       0.0445
# Kurtosis:                       3.546   Cond. No.                         543.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Restricted Model

# %%
dfFactor_normal, _ = minmaxscaler_for_train(Factor)

Y = LogExcessReturn['mean']

name = [
    'tech_class0', 'tech_class1', 'tech_class2',
       'tech_class3', 'tech_class4', 'tech_class5', 'tech_class6',
       'tech_class7', 'tech_class8', 'tech_class9'
]

model = sm.OLS(Y, dfFactor_normal[name]).fit()
result = model.summary()
print(result)
print("\n\n")
# print(result.tables[0][0][3].data)

GOODFactor['tech_pca_total_minmax'] = (dfFactor_normal[name] * model.params).sum(axis=1)

for i in range(2, 6):
    Y = LogExcessReturn['yr' + str(i)]
    model = sm.OLS(Y, GOODFactor['tech_pca_total_minmax']).fit()
    result = model.summary()
    print(result)
    print("\n\n")
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   mean   R-squared:                       0.170
# Model:                            OLS   Adj. R-squared:                  0.146
# Method:                 Least Squares   F-statistic:                     7.129
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           3.11e-10
# Time:                        19:23:35   Log-Likelihood:                -1013.0
# No. Observations:                 359   AIC:                             2046.
# Df Residuals:                     349   BIC:                             2085.
# Df Model:                          10
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# tech_class0   -67.7508     86.212     -0.786      0.432    -237.311     101.809
# tech_class1    44.3827     47.913      0.926      0.355     -49.851     138.616
# tech_class2   -10.2435      6.962     -1.471      0.142     -23.936       3.449
# tech_class3     0.8674      1.994      0.435      0.664      -3.054       4.789
# tech_class4    15.4204     48.263      0.320      0.750     -79.503     110.344
# tech_class5     8.2707      4.095      2.020      0.044       0.216      16.325
# tech_class6    -2.6192      3.167     -0.827      0.409      -8.848       3.610
# tech_class7    15.4204      6.878      2.242      0.026       1.893      28.948
# tech_class8     2.3824      2.335      1.020      0.308      -2.211       6.976
# tech_class9     0.8509      3.443      0.247      0.805      -5.921       7.623
# ==============================================================================
# Omnibus:                        7.506   Durbin-Watson:                   0.150
# Prob(Omnibus):                  0.023   Jarque-Bera (JB):                8.790
# Skew:                          -0.223   Prob(JB):                       0.0123
# Kurtosis:                       3.624   Cond. No.                         543.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    yr2   R-squared:                       0.201
# Model:                            OLS   Adj. R-squared:                  0.199
# Method:                 Least Squares   F-statistic:                     89.91
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           3.55e-19
# Time:                        19:23:35   Log-Likelihood:                -732.63
# No. Observations:                 359   AIC:                             1467.
# Df Residuals:                     358   BIC:                             1471.
# Df Model:                           1
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# tech_pca_total_minmax     0.5077      0.054      9.482      0.000       0.402       0.613
# ==============================================================================
# Omnibus:                        8.484   Durbin-Watson:                   0.165
# Prob(Omnibus):                  0.014   Jarque-Bera (JB):               13.166
# Skew:                          -0.121   Prob(JB):                      0.00138
# Kurtosis:                       3.906   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    yr3   R-squared:                       0.180
# Model:                            OLS   Adj. R-squared:                  0.178
# Method:                 Least Squares   F-statistic:                     78.74
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           3.44e-17
# Time:                        19:23:35   Log-Likelihood:                -961.19
# No. Observations:                 359   AIC:                             1924.
# Df Residuals:                     358   BIC:                             1928.
# Df Model:                           1
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# tech_pca_total_minmax     0.8981      0.101      8.874      0.000       0.699       1.097
# ==============================================================================
# Omnibus:                        9.408   Durbin-Watson:                   0.150
# Prob(Omnibus):                  0.009   Jarque-Bera (JB):               11.775
# Skew:                          -0.249   Prob(JB):                      0.00277
# Kurtosis:                       3.735   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    yr4   R-squared:                       0.169
# Model:                            OLS   Adj. R-squared:                  0.167
# Method:                 Least Squares   F-statistic:                     72.95
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           3.87e-16
# Time:                        19:23:35   Log-Likelihood:                -1082.4
# No. Observations:                 359   AIC:                             2167.
# Df Residuals:                     358   BIC:                             2171.
# Df Model:                           1
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# tech_pca_total_minmax     1.2117      0.142      8.541      0.000       0.933       1.491
# ==============================================================================
# Omnibus:                        6.849   Durbin-Watson:                   0.147
# Prob(Omnibus):                  0.033   Jarque-Bera (JB):                7.739
# Skew:                          -0.217   Prob(JB):                       0.0209
# Kurtosis:                       3.573   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    yr5   R-squared:                       0.149
# Model:                            OLS   Adj. R-squared:                  0.147
# Method:                 Least Squares   F-statistic:                     62.84
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           2.87e-14
# Time:                        19:23:35   Log-Likelihood:                -1156.5
# No. Observations:                 359   AIC:                             2315.
# Df Residuals:                     358   BIC:                             2319.
# Df Model:                           1
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# tech_pca_total_minmax     1.3824      0.174      7.927      0.000       1.039       1.725
# ==============================================================================
# Omnibus:                        6.995   Durbin-Watson:                   0.165
# Prob(Omnibus):                  0.030   Jarque-Bera (JB):                7.805
# Skew:                          -0.227   Prob(JB):                       0.0202
# Kurtosis:                       3.561   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
result = pd.DataFrame()
for i in range(2, 6):
    Y = LogExcessReturn['yr' + str(i)]
    model = sm.OLS(Y, GOODFactor['tech_pca_total_minmax']).fit()
    df = get_coef_table(model,i)
    #result = model.summary()
    #print(result)
    result = result.append(df)
result
# Out:
#                  coef Name  coef.  std err  pvalue  [ 0.025  0.975 ]  \
# yr2  tech_pca_total_minmax   0.51     0.05     0.0     0.40     0.61
# yr3  tech_pca_total_minmax   0.90     0.10     0.0     0.70     1.10
# yr4  tech_pca_total_minmax   1.21     0.14     0.0     0.93     1.49
# yr5  tech_pca_total_minmax   1.38     0.17     0.0     1.04     1.73
#
#      R-sqaured
# yr2       0.20
# yr3       0.18
# yr4       0.17
# yr5       0.15

# %% [markdown]
# ## 宏观因子

# %% [markdown]
# ### Unrestricted Model

# %%
dfFactor_normal, _ = minmaxscaler_for_train(Factor)

name = [
    'labor_market', 
    'housing', 
    'consumption', 
    'money', 
    'bond_ex', 
    'price', 
    'stock'
]

for i in range(2, 6):
    Y = LogExcessReturn['yr' + str(i)]
    model = sm.OLS(Y, dfFactor_normal[name]).fit()
    result = model.summary()
    print(result)
    print("\n\n")
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    yr2   R-squared:                       0.575
# Model:                            OLS   Adj. R-squared:                  0.567
# Method:                 Least Squares   F-statistic:                     68.04
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           1.26e-61
# Time:                        19:25:30   Log-Likelihood:                -619.25
# No. Observations:                 359   AIC:                             1253.
# Df Residuals:                     352   BIC:                             1280.
# Df Model:                           7
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# labor_market     0.2893      0.527      0.549      0.583      -0.747       1.326
# housing         -0.4369      0.390     -1.120      0.264      -1.204       0.330
# consumption     -0.1387      0.559     -0.248      0.804      -1.238       0.961
# money            1.9143      0.851      2.250      0.025       0.241       3.587
# bond_ex         -5.6639      0.513    -11.043      0.000      -6.673      -4.655
# price            4.9899      0.374     13.356      0.000       4.255       5.725
# stock           -1.3693      0.657     -2.085      0.038      -2.661      -0.078
# ==============================================================================
# Omnibus:                       12.622   Durbin-Watson:                   0.356
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               13.423
# Skew:                           0.471   Prob(JB):                      0.00122
# Kurtosis:                       2.901   Cond. No.                         15.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    yr3   R-squared:                       0.535
# Model:                            OLS   Adj. R-squared:                  0.526
# Method:                 Least Squares   F-statistic:                     57.94
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           6.93e-55
# Time:                        19:25:30   Log-Likelihood:                -859.28
# No. Observations:                 359   AIC:                             1733.
# Df Residuals:                     352   BIC:                             1760.
# Df Model:                           7
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# labor_market     0.5889      1.029      0.572      0.567      -1.434       2.612
# housing         -1.1591      0.761     -1.523      0.129      -2.656       0.338
# consumption     -0.8927      1.091     -0.818      0.414      -3.038       1.252
# money            3.8261      1.660      2.305      0.022       0.561       7.091
# bond_ex        -10.1586      1.001    -10.150      0.000     -12.127      -8.190
# price            9.4764      0.729     12.997      0.000       8.042      10.910
# stock           -2.7546      1.282     -2.149      0.032      -5.275      -0.234
# ==============================================================================
# Omnibus:                        8.059   Durbin-Watson:                   0.322
# Prob(Omnibus):                  0.018   Jarque-Bera (JB):                8.157
# Skew:                           0.344   Prob(JB):                       0.0169
# Kurtosis:                       2.734   Cond. No.                         15.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    yr4   R-squared:                       0.508
# Model:                            OLS   Adj. R-squared:                  0.498
# Method:                 Least Squares   F-statistic:                     51.82
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           1.72e-50
# Time:                        19:25:30   Log-Likelihood:                -988.59
# No. Observations:                 359   AIC:                             1991.
# Df Residuals:                     352   BIC:                             2018.
# Df Model:                           7
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# labor_market     0.6793      1.475      0.461      0.645      -2.221       3.579
# housing         -2.0389      1.091     -1.868      0.063      -4.185       0.108
# consumption     -1.4047      1.564     -0.898      0.370      -4.480       1.671
# money            5.6519      2.380      2.375      0.018       0.971      10.332
# bond_ex        -13.3692      1.435     -9.317      0.000     -16.191     -10.547
# price           13.2500      1.045     12.676      0.000      11.194      15.306
# stock           -4.2283      1.837     -2.301      0.022      -7.842      -0.615
# ==============================================================================
# Omnibus:                        6.585   Durbin-Watson:                   0.323
# Prob(Omnibus):                  0.037   Jarque-Bera (JB):                6.759
# Skew:                           0.324   Prob(JB):                       0.0341
# Kurtosis:                       2.820   Cond. No.                         15.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    yr5   R-squared:                       0.475
# Model:                            OLS   Adj. R-squared:                  0.465
# Method:                 Least Squares   F-statistic:                     45.57
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           9.87e-46
# Time:                        19:25:30   Log-Likelihood:                -1069.7
# No. Observations:                 359   AIC:                             2153.
# Df Residuals:                     352   BIC:                             2181.
# Df Model:                           7
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# labor_market     0.9360      1.849      0.506      0.613      -2.700       4.572
# housing         -2.6977      1.368     -1.972      0.049      -5.389      -0.007
# consumption     -2.1958      1.960     -1.120      0.263      -6.051       1.659
# money            7.0298      2.984      2.356      0.019       1.162      12.898
# bond_ex        -15.4245      1.799     -8.575      0.000     -18.962     -11.887
# price           16.2246      1.310     12.382      0.000      13.647      18.802
# stock           -5.8730      2.303     -2.550      0.011     -10.403      -1.343
# ==============================================================================
# Omnibus:                        4.586   Durbin-Watson:                   0.346
# Prob(Omnibus):                  0.101   Jarque-Bera (JB):                4.687
# Skew:                           0.269   Prob(JB):                       0.0960
# Kurtosis:                       2.843   Cond. No.                         15.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Restricted Model

# %%
dfFactor_normal, _ = minmaxscaler_for_train(Factor)

Y = LogExcessReturn['mean']

name = [
    'labor_market', 
    'housing', 
    'consumption', 
    'money', 
    'bond_ex', 
    'price', 
    'stock'
]

model = sm.OLS(Y, dfFactor_normal[name]).fit()
result = model.summary()
print(result)
print("\n\n")
# print(result.tables[0][0][3].data)

GOODFactor['macro_pca_total_minmax'] = (dfFactor_normal[name] * model.params).sum(axis=1)

for i in range(2, 6):
    Y = LogExcessReturn['yr' + str(i)]
    model = sm.OLS(Y, GOODFactor['macro_pca_total_minmax']).fit()
    result = model.summary()
    print(result)
    print("\n\n")
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   mean   R-squared:                       0.514
# Model:                            OLS   Adj. R-squared:                  0.505
# Method:                 Least Squares   F-statistic:                     53.24
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           1.56e-51
# Time:                        19:25:33   Log-Likelihood:                -916.79
# No. Observations:                 359   AIC:                             1848.
# Df Residuals:                     352   BIC:                             1875.
# Df Model:                           7
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# labor_market     0.6234      1.207      0.516      0.606      -1.751       2.998
# housing         -1.5831      0.894     -1.772      0.077      -3.340       0.174
# consumption     -1.1580      1.280     -0.905      0.366      -3.676       1.360
# money            4.6055      1.948      2.364      0.019       0.773       8.438
# bond_ex        -11.1540      1.175     -9.495      0.000     -13.464      -8.844
# price           10.9852      0.856     12.837      0.000       9.302      12.668
# stock           -3.5563      1.504     -2.364      0.019      -6.515      -0.598
# ==============================================================================
# Omnibus:                        7.007   Durbin-Watson:                   0.328
# Prob(Omnibus):                  0.030   Jarque-Bera (JB):                7.199
# Skew:                           0.334   Prob(JB):                       0.0273
# Kurtosis:                       2.810   Cond. No.                         15.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    yr2   R-squared:                       0.571
# Model:                            OLS   Adj. R-squared:                  0.570
# Method:                 Least Squares   F-statistic:                     476.3
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           9.51e-68
# Time:                        19:25:33   Log-Likelihood:                -620.99
# No. Observations:                 359   AIC:                             1244.
# Df Residuals:                     358   BIC:                             1248.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# macro_pca_total_minmax     0.4917      0.023     21.823      0.000       0.447       0.536
# ==============================================================================
# Omnibus:                       14.967   Durbin-Watson:                   0.359
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               16.167
# Skew:                           0.518   Prob(JB):                     0.000309
# Kurtosis:                       2.913   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    yr3   R-squared:                       0.535
# Model:                            OLS   Adj. R-squared:                  0.533
# Method:                 Least Squares   F-statistic:                     411.6
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           1.85e-61
# Time:                        19:25:33   Log-Likelihood:                -859.51
# No. Observations:                 359   AIC:                             1721.
# Df Residuals:                     358   BIC:                             1725.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# macro_pca_total_minmax     0.8883      0.044     20.287      0.000       0.802       0.974
# ==============================================================================
# Omnibus:                        8.716   Durbin-Watson:                   0.324
# Prob(Omnibus):                  0.013   Jarque-Bera (JB):                8.846
# Skew:                           0.360   Prob(JB):                       0.0120
# Kurtosis:                       2.730   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    yr4   R-squared:                       0.507
# Model:                            OLS   Adj. R-squared:                  0.506
# Method:                 Least Squares   F-statistic:                     368.8
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           5.22e-57
# Time:                        19:25:33   Log-Likelihood:                -988.61
# No. Observations:                 359   AIC:                             1979.
# Df Residuals:                     358   BIC:                             1983.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# macro_pca_total_minmax     1.2050      0.063     19.205      0.000       1.082       1.328
# ==============================================================================
# Omnibus:                        6.547   Durbin-Watson:                   0.324
# Prob(Omnibus):                  0.038   Jarque-Bera (JB):                6.722
# Skew:                           0.323   Prob(JB):                       0.0347
# Kurtosis:                       2.824   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    yr5   R-squared:                       0.474
# Model:                            OLS   Adj. R-squared:                  0.473
# Method:                 Least Squares   F-statistic:                     323.0
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           6.28e-52
# Time:                        19:25:33   Log-Likelihood:                -1070.1
# No. Observations:                 359   AIC:                             2142.
# Df Residuals:                     358   BIC:                             2146.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# macro_pca_total_minmax     1.4150      0.079     17.972      0.000       1.260       1.570
# ==============================================================================
# Omnibus:                        3.928   Durbin-Watson:                   0.342
# Prob(Omnibus):                  0.140   Jarque-Bera (JB):                4.007
# Skew:                           0.250   Prob(JB):                        0.135
# Kurtosis:                       2.870   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
result = pd.DataFrame()
for i in range(2, 6):
    Y = LogExcessReturn['yr' + str(i)]
    model = sm.OLS(Y, GOODFactor['macro_pca_total_minmax']).fit()
    df = get_coef_table(model,i)
    #result = model.summary()
    #print(result)
    result = result.append(df)
result
# Out:
#                   coef Name  coef.  std err  pvalue  [ 0.025  0.975 ]  \
# yr2  macro_pca_total_minmax   0.49     0.02     0.0     0.45     0.54
# yr3  macro_pca_total_minmax   0.89     0.04     0.0     0.80     0.97
# yr4  macro_pca_total_minmax   1.20     0.06     0.0     1.08     1.33
# yr5  macro_pca_total_minmax   1.41     0.08     0.0     1.26     1.57
#
#      R-sqaured
# yr2       0.57
# yr3       0.53
# yr4       0.51
# yr5       0.47

# %% [markdown]
# ## 金融指标

# %% [markdown]
# ### Unrestricted Model

# %%
dfFactor_normal, _ = minmaxscaler_for_train(Factor)

name = [
    'PYD', 
    'RiF',
    'Industries', 
    'SizeBM'
]

for i in range(2, 6):
    Y = LogExcessReturn['yr' + str(i)]
    model = sm.OLS(Y, dfFactor_normal[name]).fit()
    result = model.summary()
    print(result)
    print("\n\n")
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    yr2   R-squared:                       0.170
# Model:                            OLS   Adj. R-squared:                  0.160
# Method:                 Least Squares   F-statistic:                     18.15
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           1.42e-13
# Time:                        19:29:25   Log-Likelihood:                -739.45
# No. Observations:                 359   AIC:                             1487.
# Df Residuals:                     355   BIC:                             1502.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# PYD            0.1877      0.431      0.435      0.664      -0.660       1.036
# RiF            1.6045      0.654      2.453      0.015       0.318       2.891
# Industries     2.1048      3.413      0.617      0.538      -4.608       8.817
# SizeBM        -2.0094      3.351     -0.600      0.549      -8.599       4.580
# ==============================================================================
# Omnibus:                       10.122   Durbin-Watson:                   0.160
# Prob(Omnibus):                  0.006   Jarque-Bera (JB):               11.642
# Skew:                          -0.301   Prob(JB):                      0.00296
# Kurtosis:                       3.645   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    yr3   R-squared:                       0.141
# Model:                            OLS   Adj. R-squared:                  0.131
# Method:                 Least Squares   F-statistic:                     14.59
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           4.84e-11
# Time:                        19:29:25   Log-Likelihood:                -969.56
# No. Observations:                 359   AIC:                             1947.
# Df Residuals:                     355   BIC:                             1963.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# PYD           -0.5518      0.819     -0.674      0.501      -2.162       1.058
# RiF            3.5189      1.242      2.834      0.005       1.077       5.961
# Industries     1.9548      6.479      0.302      0.763     -10.787      14.697
# SizeBM        -1.3383      6.360     -0.210      0.833     -13.847      11.170
# ==============================================================================
# Omnibus:                        7.379   Durbin-Watson:                   0.151
# Prob(Omnibus):                  0.025   Jarque-Bera (JB):                7.404
# Skew:                          -0.292   Prob(JB):                       0.0247
# Kurtosis:                       3.391   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    yr4   R-squared:                       0.133
# Model:                            OLS   Adj. R-squared:                  0.123
# Method:                 Least Squares   F-statistic:                     13.59
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           2.56e-10
# Time:                        19:29:25   Log-Likelihood:                -1090.2
# No. Observations:                 359   AIC:                             2188.
# Df Residuals:                     355   BIC:                             2204.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# PYD           -1.0647      1.146     -0.929      0.353      -3.318       1.188
# RiF            5.1975      1.738      2.991      0.003       1.780       8.615
# Industries     1.1123      9.066      0.123      0.902     -16.717      18.942
# SizeBM        -0.2490      8.900     -0.028      0.978     -17.752      17.254
# ==============================================================================
# Omnibus:                        4.563   Durbin-Watson:                   0.149
# Prob(Omnibus):                  0.102   Jarque-Bera (JB):                4.302
# Skew:                          -0.235   Prob(JB):                        0.116
# Kurtosis:                       3.260   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    yr5   R-squared:                       0.113
# Model:                            OLS   Adj. R-squared:                  0.103
# Method:                 Least Squares   F-statistic:                     11.35
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           1.12e-08
# Time:                        19:29:25   Log-Likelihood:                -1163.9
# No. Observations:                 359   AIC:                             2336.
# Df Residuals:                     355   BIC:                             2351.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# PYD           -1.7045      1.407     -1.211      0.227      -4.472       1.063
# RiF            6.7483      2.134      3.162      0.002       2.551      10.946
# Industries    -2.0684     11.135     -0.186      0.853     -23.967      19.830
# SizeBM         2.8582     10.930      0.261      0.794     -18.638      24.355
# ==============================================================================
# Omnibus:                        3.702   Durbin-Watson:                   0.166
# Prob(Omnibus):                  0.157   Jarque-Bera (JB):                3.417
# Skew:                          -0.215   Prob(JB):                        0.181
# Kurtosis:                       3.209   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Restricted Model

# %%
dfFactor_normal, _ = minmaxscaler_for_train(Factor)

Y = LogExcessReturn['mean']

name = [
    'PYD', 
    'RiF',
    'Industries', 
    'SizeBM'
]

model = sm.OLS(Y, dfFactor_normal[name]).fit()
result = model.summary()
print(result)
print("\n\n")
# print(result.tables[0][0][3].data)

GOODFactor['financial_pca_total_minmax'] = (dfFactor_normal[name] * model.params).sum(axis=1)

for i in range(2, 6):
    Y = LogExcessReturn['yr' + str(i)]
    model = sm.OLS(Y, GOODFactor['financial_pca_total_minmax']).fit()
    result = model.summary()
    print(result)
    print("\n\n")
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   mean   R-squared:                       0.132
# Model:                            OLS   Adj. R-squared:                  0.122
# Method:                 Least Squares   F-statistic:                     13.48
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           3.06e-10
# Time:                        19:29:27   Log-Likelihood:                -1021.0
# No. Observations:                 359   AIC:                             2050.
# Df Residuals:                     355   BIC:                             2066.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# PYD           -0.7833      0.945     -0.829      0.408      -2.642       1.075
# RiF            4.2673      1.433      2.977      0.003       1.448       7.086
# Industries     0.7759      7.478      0.104      0.917     -13.930      15.482
# SizeBM        -0.1846      7.341     -0.025      0.980     -14.621      14.252
# ==============================================================================
# Omnibus:                        5.273   Durbin-Watson:                   0.151
# Prob(Omnibus):                  0.072   Jarque-Bera (JB):                5.046
# Skew:                          -0.252   Prob(JB):                       0.0802
# Kurtosis:                       3.288   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    yr2   R-squared:                       0.165
# Model:                            OLS   Adj. R-squared:                  0.162
# Method:                 Least Squares   F-statistic:                     70.50
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           1.09e-15
# Time:                        19:29:27   Log-Likelihood:                -740.58
# No. Observations:                 359   AIC:                             1483.
# Df Residuals:                     358   BIC:                             1487.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# financial_pca_total_minmax     0.5213      0.062      8.397      0.000       0.399       0.643
# ==============================================================================
# Omnibus:                        5.523   Durbin-Watson:                   0.164
# Prob(Omnibus):                  0.063   Jarque-Bera (JB):                6.074
# Skew:                          -0.184   Prob(JB):                       0.0480
# Kurtosis:                       3.520   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    yr3   R-squared:                       0.141
# Model:                            OLS   Adj. R-squared:                  0.139
# Method:                 Least Squares   F-statistic:                     58.74
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           1.71e-13
# Time:                        19:29:27   Log-Likelihood:                -969.60
# No. Observations:                 359   AIC:                             1941.
# Df Residuals:                     358   BIC:                             1945.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# financial_pca_total_minmax     0.9006      0.118      7.664      0.000       0.669       1.132
# ==============================================================================
# Omnibus:                        6.642   Durbin-Watson:                   0.153
# Prob(Omnibus):                  0.036   Jarque-Bera (JB):                6.585
# Skew:                          -0.276   Prob(JB):                       0.0372
# Kurtosis:                       3.368   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    yr4   R-squared:                       0.133
# Model:                            OLS   Adj. R-squared:                  0.130
# Method:                 Least Squares   F-statistic:                     54.80
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           9.64e-13
# Time:                        19:29:27   Log-Likelihood:                -1090.2
# No. Observations:                 359   AIC:                             2182.
# Df Residuals:                     358   BIC:                             2186.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# financial_pca_total_minmax     1.2170      0.164      7.402      0.000       0.894       1.540
# ==============================================================================
# Omnibus:                        4.791   Durbin-Watson:                   0.149
# Prob(Omnibus):                  0.091   Jarque-Bera (JB):                4.534
# Skew:                          -0.242   Prob(JB):                        0.104
# Kurtosis:                       3.262   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    yr5   R-squared:                       0.113
# Model:                            OLS   Adj. R-squared:                  0.110
# Method:                 Least Squares   F-statistic:                     45.41
# Date:                Sat, 08 Dec 2018   Prob (F-statistic):           6.41e-11
# Time:                        19:29:27   Log-Likelihood:                -1164.1
# No. Observations:                 359   AIC:                             2330.
# Df Residuals:                     358   BIC:                             2334.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# financial_pca_total_minmax     1.3612      0.202      6.738      0.000       0.964       1.758
# ==============================================================================
# Omnibus:                        4.901   Durbin-Watson:                   0.163
# Prob(Omnibus):                  0.086   Jarque-Bera (JB):                4.635
# Skew:                          -0.250   Prob(JB):                       0.0985
# Kurtosis:                       3.243   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
result = pd.DataFrame()
for i in range(2, 6):
    Y = LogExcessReturn['yr' + str(i)]
    model = sm.OLS(Y, GOODFactor['financial_pca_total_minmax']).fit()
    df = get_coef_table(model,i)
    #result = model.summary()
    #print(result)
    result = result.append(df)
result
# Out:
#                       coef Name  coef.  std err  pvalue  [ 0.025  0.975 ]  \
# yr2  financial_pca_total_minmax   0.52     0.06     0.0     0.40     0.64
# yr3  financial_pca_total_minmax   0.90     0.12     0.0     0.67     1.13
# yr4  financial_pca_total_minmax   1.22     0.16     0.0     0.89     1.54
# yr5  financial_pca_total_minmax   1.36     0.20     0.0     0.96     1.76
#
#      R-sqaured
# yr2       0.16
# yr3       0.14
# yr4       0.13
# yr5       0.11
